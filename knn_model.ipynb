# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import acquire as a 
import prepare as p

# %%
df = a.get_titanic_data()

# %%
df = p.prep_titanic(df)

# %%
df = df.drop(columns= ['Unnamed: 0', 'embark_town'])

# %%
#Train Test Split 
from sklearn.model_selection import train_test_split


train, validate = train_test_split(df, test_size= 0.7)
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare  alone  \
# 242         0       2    male  29.000000      0      0  10.5000      1
# 617         0       3  female  26.000000      1      0  16.1000      0
# 121         0       3    male  29.699118      0      0   8.0500      1
# 600         1       2  female  24.000000      2      1  27.0000      0
# 407         1       2    male   3.000000      1      1  18.7500      0
# ..        ...     ...     ...        ...    ...    ...      ...    ...
# 432         1       2  female  42.000000      1      0  26.0000      0
# 176         0       3    male  29.699118      3      1  25.4667      0
# 510         1       3    male  29.000000      0      0   7.7500      1
# 51          0       3    male  21.000000      0      0   7.8000      1
# 562         0       2    male  28.000000      0      0  13.5000      1
#
#      sex_male  embark_town_Queenstown  embark_town_Southampton
# ...

# %%
y_col = train['survived']
X_ cols = train
